# %% [markdown]
# ## Simple Linear Regression. Minimal Example

# %% [markdown]
# ### Import the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Generate random input data to train on

# %%
observations = 1000

xs=np.random.uniform(low=-10,high=10,size=(observations,1))
zs=np.random.uniform(-10,10,(observations,1))

inputs = np.column_stack((xs,zs))

print (inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# ### Create targets we will aim at

# %%
noise = np.random.uniform(-1,1,(observations,1))

targets = 2*xs - 3*zs + 5 + noise

print (targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ### Plot the training data
# the point is to see that there is a strong trend that our model should learn to reproduce.

# %%
targets = targets.reshape(observations,)
fig = plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.plot(xs,zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('Targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# ### Initialize Variables

# %%
init_range = 0.1

weights = np.random.uniform(-init_range,init_range, size=(2,1))

biases = np.random.uniform(-init_range, init_range, size=1)

print(weights)
print(biases)
# Out:
# [[0.0311796 ]
#  [0.02199524]]
# [0.02073258]

# %% [markdown]
# ### Set a learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# ### Train the model

# %%
for i in range (100):
    outputs =  np.dot(inputs,weights) + biases
    deltas = outputs - targets
    
    loss=np.sum(deltas ** 2) / 2 / observations
    
    print (loss)
    
    deltas_scaled = deltas / observations
    
    weights = weights - learning_rate * np.dot(inputs.T,deltas_scaled)
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 226.898441540164
# 36.86355202179804
# 14.35866203883021
# 11.348727667349477
# 10.621728974574937
# 10.175235302324564
# 9.775700568644075
# 9.395381518458203
# 9.030505097775302
# 8.680109643416625
# 8.343581440322447
# 8.020367135366323
# 7.709939468313581
# 7.411792527061466
# 7.125440470717125
# 6.850416685205004
# 6.586273016774805
# 6.33257904101571
# 6.088921361392722
# 5.85490293560372
# 5.63014242859444
# 5.414273591169573
# 5.20694466318651
# 5.007817800359138
# 4.816568523737644
# 4.632885190967245
# 4.456468488464285
# 4.287030943682141
# 4.124296456672217
# 3.9679998501766924
# 3.8178864375198676
# 3.673711607594035
# 3.5352404262635297
# 3.402247253537551
# 3.2745153758878165
# 3.1518366531120003
# 3.034011179167463
# 2.9208469564226265
# 2.8121595827951564
# 2.7077719512671883
# 2.607513961287893
# 2.511222241593159
# 2.418739883990693
# 2.329916187676774
# 2.244606413667971
# 2.1626715489477317
# 2.0839780799434475
# 2.008397774964943
# 1.9358074752498209
# ...

# %% [markdown]
# ### Print weights and Biases and see if we have worked correctly.

# %%
print (weights,biases)
# Out:
# [[ 1.99522314]
#  [-2.99736237]] [4.31711709]

# %% [markdown]
# ### plot last outputs vs target

# %% [markdown]
# cuando estamos al fin de nuestra entrenamiento, Esto se representa el final con precision
# y cerca del punto de linea de 45 grado , el target de ese valores de la salida son.

# %%
plt.plot(outputs,targets)
plt.xlabel('outputs')
plt.ylabel('inputs')
plt.show()
